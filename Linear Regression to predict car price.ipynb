# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline


headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df=pd.read_csv('Desktop//car.txt',names=headers)
df.head(2)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
#
# [2 rows x 26 columns]

# %%
df.replace('?',np.nan,inplace=True)
df
#df.isnull().sum()
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
print(df.shape)
df.isnull().sum()
# Out:
# (205, 27)
# symboling            4
# normalized-losses    0
# make                 4
# aspiration           4
# num-of-doors         6
# body-style           4
# drive-wheels         4
# engine-location      4
# wheel-base           4
# length               4
# width                4
# height               4
# curb-weight          4
# engine-type          4
# num-of-cylinders     4
# engine-size          4
# fuel-system          4
# bore                 0
# stroke               0
# compression-ratio    4
# horsepower           0
# peak-rpm             0
# city-mpg             4
# highway-mpg          4
# price                4
# diesel               0
# gas                  0
# dtype: int64

# %%
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df

df['normalized-losses'].replace(np.nan,df['normalized-losses'].astype('float').mean()
,inplace=True)
df['stroke'].replace(np.nan,df['stroke'].astype('float').mean(),inplace=True)
df['bore'].replace(np.nan,df['bore'].astype('float').mean(),inplace=True)
df['peak-rpm'].replace(np.nan,df['horsepower'].astype('float').mean(),inplace=True)
df['horsepower'].replace(np.nan,df['peak-rpm'].astype('float').mean(),inplace=True)
df1=df
df1
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3.0              122.0  alfa-romero        std          two
# 1          3.0              122.0  alfa-romero        std          two
# 2          1.0              122.0  alfa-romero        std          two
# 3          2.0              164.0         audi        std         four
# 4          2.0              164.0         audi        std         four
# ..         ...                ...          ...        ...          ...
# 204       -1.0               95.0        volvo      turbo         four
# 9          NaN              122.0          NaN        NaN          NaN
# 44         NaN              122.0          NaN        NaN          NaN
# 45         NaN              122.0          NaN        NaN          NaN
# 129        NaN              122.0          NaN        NaN          NaN
#
#       body-style drive-wheels engine-location  wheel-base  length  ...  \
# ...

# %%
df1.isnull().sum()
# Out:
# symboling            4
# normalized-losses    0
# make                 4
# aspiration           4
# num-of-doors         6
# body-style           4
# drive-wheels         4
# engine-location      4
# wheel-base           4
# length               4
# width                4
# height               4
# curb-weight          4
# engine-type          4
# num-of-cylinders     4
# engine-size          4
# fuel-system          4
# bore                 0
# stroke               0
# compression-ratio    4
# horsepower           0
# peak-rpm             0
# city-mpg             4
# highway-mpg          4
# price                4
# diesel               0
# gas                  0
# dtype: int64

# %%
df[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float")
df["normalized-losses"] = df["normalized-losses"].astype("int")
df["price"] = df["price"].astype("float")
df["peak-rpm"] = df["peak-rpm"].astype("float")
df['horsepower']=df['horsepower'].astype('float')

# %%
print(df['fuel-type'].value_counts())

fuel_variable=pd.get_dummies(df['fuel-type'])
fuel_variable.head(2)
# Out:
# gas       185
# diesel     20
# Name: fuel-type, dtype: int64
#    diesel  gas
# 0       0    1
# 1       0    1

# %%
df.dropna(subset=['price'],inplace=True)

# %%
df1.isna().sum()
# Out:
# symboling            4
# normalized-losses    0
# make                 4
# aspiration           4
# num-of-doors         6
# body-style           4
# drive-wheels         4
# engine-location      4
# wheel-base           4
# length               4
# width                4
# height               4
# curb-weight          4
# engine-type          4
# num-of-cylinders     4
# engine-size          4
# fuel-system          4
# bore                 0
# stroke               0
# compression-ratio    4
# horsepower           0
# peak-rpm             0
# city-mpg             4
# highway-mpg          4
# price                4
# diesel               0
# gas                  0
# dtype: int64

# %%
df = pd.concat([df,fuel_variable],axis=1)
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0          3.0              122.0  alfa-romero       gas        std
# 1          3.0              122.0  alfa-romero       gas        std
# 2          1.0              122.0  alfa-romero       gas        std
# 3          2.0              164.0         audi       gas        std
# 4          2.0              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 204       -1.0               95.0        volvo       gas      turbo
# 9          NaN                NaN          NaN       NaN        NaN
# 44         NaN                NaN          NaN       NaN        NaN
# 45         NaN                NaN          NaN       NaN        NaN
# 129        NaN                NaN          NaN       NaN        NaN
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
df = df.drop('fuel-type', axis=1)
df.head(2)
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0        3.0              122.0  alfa-romero        std          two
# 1        3.0              122.0  alfa-romero        std          two
#
#     body-style drive-wheels engine-location  wheel-base  length  ...  bore  \
# 0  convertible          rwd           front        88.6   168.8  ...  3.47
# 1  convertible          rwd           front        88.6   168.8  ...  3.47
#
#    stroke  compression-ratio horsepower peak-rpm  city-mpg highway-mpg  \
# 0    2.68                9.0      111.0   5000.0      21.0        27.0
# 1    2.68                9.0      111.0   5000.0      21.0        27.0
#
#      price  diesel  gas
# 0  13495.0       0    1
# 1  16500.0       0    1
#
# [2 rows x 27 columns]

# %%
data=df.corr()
data
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008153           0.055045    0.158018  0.123952
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.018422           0.016363   -0.016600  0.083903
# ...

# %%
sns.heatmap(data,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
x = df.drop('price',axis = 1)
x
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3.0              122.0  alfa-romero        std          two
# 1          3.0              122.0  alfa-romero        std          two
# 2          1.0              122.0  alfa-romero        std          two
# 3          2.0              164.0         audi        std         four
# 4          2.0              164.0         audi        std         four
# ..         ...                ...          ...        ...          ...
# 204       -1.0               95.0        volvo      turbo         four
# 9          NaN                NaN          NaN        NaN          NaN
# 44         NaN                NaN          NaN        NaN          NaN
# 45         NaN                NaN          NaN        NaN          NaN
# 129        NaN                NaN          NaN        NaN          NaN
#
#       body-style drive-wheels engine-location  wheel-base  length  ...  \
# ...

# %%
y = df['price']
y
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 204    22625.0
# 9          NaN
# 44         NaN
# 45         NaN
# 129        NaN
# Name: price, Length: 205, dtype: float64

# %%
df
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3.0              122.0  alfa-romero        std          two
# 1          3.0              122.0  alfa-romero        std          two
# 2          1.0              122.0  alfa-romero        std          two
# 3          2.0              164.0         audi        std         four
# 4          2.0              164.0         audi        std         four
# ..         ...                ...          ...        ...          ...
# 204       -1.0               95.0        volvo      turbo         four
# 9          NaN                NaN          NaN        NaN          NaN
# 44         NaN                NaN          NaN        NaN          NaN
# 45         NaN                NaN          NaN        NaN          NaN
# 129        NaN                NaN          NaN        NaN          NaN
#
#       body-style drive-wheels engine-location  wheel-base  length  ...  bore  \
# ...

# %%
df.isnull().sum()
# Out:
# symboling            4
# normalized-losses    4
# make                 4
# aspiration           4
# num-of-doors         6
# body-style           4
# drive-wheels         4
# engine-location      4
# wheel-base           4
# length               4
# width                4
# height               4
# curb-weight          4
# engine-type          4
# num-of-cylinders     4
# engine-size          4
# fuel-system          4
# bore                 4
# stroke               4
# compression-ratio    4
# horsepower           4
# peak-rpm             4
# city-mpg             4
# highway-mpg          4
# price                4
# diesel               0
# gas                  0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train ,x_test, y_train, y_test= train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18744\3870188101.py in <module>
# ----> 1 lr.fit(x_train, y_train)
#
# ~\ana\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
#     663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#
# ~\ana\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ...

# %%
pred=lr.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18744\1617182262.py in <module>
# ----> 1 pred=lr.predict(x_test)
#       2
#
# ~\ana\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\ana\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     343         check_is_fitted(self)
#     344
# --> 345         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     346         return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     347
#
# ~\ana\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
# ...

# %%
sns.regplot(y_test,pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18744\2695697745.py in <module>
# ----> 1 sns.regplot(y_test,pred)
#
# NameError: name 'pred' is not defined
